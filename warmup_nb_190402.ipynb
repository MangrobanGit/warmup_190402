# %% [markdown]
# ### Here is a title!

# %%
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt

# %%
# Get Data
data = pd.read_csv("DatasaurusDozen.tsv", sep='\t')

# %%
# Only care about dino!
dino = data[data['dataset']=='dino']
#dino.head()

# %%
# Fixing random state for reproducibility
#np.random.seed(2925)

plt.scatter(dino['x'],dino['y'], alpha=0.5)
plt.show()
